# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdux/Introduction-to-Machine-Learning-with-Python/blob/main/06_2_%ED%8C%8C%EC%9D%B4%ED%94%84%EB%9D%BC%EC%9D%B8_%EA%B5%AC%EC%B6%95%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - `MinMaxScaler`로 데이터의 스케일을 조정하고 `SVM` 모델을 훈련시키는 워크플로

# %%
# 데이터 로드
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, random_state=0
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC

pipe = Pipeline([("scaler", MinMaxScaler()), ("svm", SVC())])

pipe.fit(X_train, y_train)

print(f"테스트 점수: {round(pipe.score(X_test, y_test), 2)}")
# Out:
# 테스트 점수: 0.97

# %% [markdown]
# - "전처리 + 분류"과정을 위해 작성해야 할 코드가 줄어듦
# - `cross_val_score`나 `GridSearchCV`에 파이프라인을 하나의 추정기처럼 사용 가능
